# %%
import pydub
import numpy as np
import matplotlib.pyplot as plt

# %%
sound = pydub.AudioSegment.from_file("./Noisy-Tap.mp3", format="mp3")

# %%
samples = sound.get_array_of_samples()
audio_sample = np.array(samples)

# %%
sound.frame_rate
# Out:
# 48000

# %%
plt.plot(
    np.arange(len(audio_sample)),
    audio_sample
)
